# %%
import sys

sys.path.insert(1, '/Users/od721/Desktop/congestion_pricing/src')

import random_instance
import gurobi_base

import pandas as pd
import numpy as np
import time

# %%
coms = [150]
seeds = [10]
network_opts = [(300,600), (350,700), (400,800),(500,1000)]

for n_commodity in coms:
    for seed in seeds:
        print('ncom_' + str(n_commodity) + '_seed_' + str(seed))
        head_ = '/Users/od721/Desktop/congestion_pricing/results/gurobi_limits/seed_'
        path_ =  head_ + str(seed) + '_k_' + str(n_commodity) + '.xlsx'
        node_ls, arc_ls = [], []
        gurobi_obj_ls, gurobi_gap_ls, gurobi_time_ls = [], [], []
        for opt in network_opts:

            # get the instance
            n_node, n_arc = opt
            node_ls.append(n_node)
            arc_ls.append(n_arc)
            ins_ = random_instance.Instance(n_node, n_arc, n_commodity, seed)

            # gurobi stats
            gurobi_start = time.time()
            obj_gurobi, gap_gurobi, _ = gurobi_base.optimize_by_gurobi(ins_, 3600, log_output=True)
            gurobi_final = time.time()
            time_gurobi = round(gurobi_final - gurobi_start, 3)
            gurobi_obj_ls.append(round(obj_gurobi,2))
            gurobi_gap_ls.append(round(gap_gurobi,2))
            gurobi_time_ls.append(time_gurobi)

        df = pd.DataFrame()
        df['num_node'] = node_ls
        df['num_arc'] = arc_ls
        df['gurobi obj'] = gurobi_obj_ls
        df['gurobi gap'] = gurobi_gap_ls
        df['gurobi time (sec)'] = gurobi_time_ls
        df.to_excel(path_, index=False)
# Out:
# ncom_150_seed_10
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-07-12
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 48000 rows, 92100 columns and 277800 nonzeros
# Model fingerprint: 0xde5ba647
# Model has 600 quadratic objective terms
# Variable types: 91500 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Found heuristic solution: objective 232997.83000
# Presolve removed 34742 rows and 57764 columns
# Presolve time: 0.21s
# Presolved: 13258 rows, 34336 columns, 117777 nonzeros
# Presolved model has 476 quadratic objective terms
# Variable types: 33949 continuous, 387 integer (387 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    40035    1.8942576e+05   1.074963e+03   0.000000e+00      5s
#    57165    2.1154283e+05   1.069435e+03   0.000000e+00     10s
#    70318    2.1901597e+05   9.308472e+02   0.000000e+00     15s
#    82278    2.2299779e+05   1.006243e+03   0.000000e+00     20s
#    92738    2.2566216e+05   3.394535e+03   0.000000e+00     25s
#   102600    2.2726479e+05   3.609580e+02   0.000000e+00     30s
#   112252    2.2807489e+05   2.443325e+01   0.000000e+00     35s
#   114068    2.2809636e+05   0.000000e+00   0.000000e+00     36s
#
# Root relaxation: objective 2.280964e+05, 114068 iterations, 35.77 seconds (141.54 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    228096.35925 228096.359  0.00%     -   36s
#
# Explored 1 nodes (114068 simplex iterations) in 36.10 seconds (141.89 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 228096
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.280963592484e+05, best bound 2.280963592484e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 56000 rows, 107450 columns and 324100 nonzeros
# Model fingerprint: 0x287c5420
# Model has 700 quadratic objective terms
# Variable types: 106750 continuous, 700 integer (700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Found heuristic solution: objective 228986.21000
# Presolve removed 39777 rows and 66550 columns
# Presolve time: 0.24s
# Presolved: 16223 rows, 40900 columns, 136002 nonzeros
# Presolved model has 560 quadratic objective terms
# Variable types: 40446 continuous, 454 integer (454 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    41883    1.8651380e+05   4.030183e+03   0.000000e+00      5s
#    60653    2.0183150e+05   5.733313e+03   0.000000e+00     10s
#    76422    2.1150587e+05   1.461100e+03   0.000000e+00     15s
#    89432    2.1484843e+05   3.662433e+03   0.000000e+00     20s
#   100901    2.1839982e+05   3.327042e+03   0.000000e+00     25s
#   111831    2.1959574e+05   2.130235e+03   0.000000e+00     30s
#   121381    2.2079976e+05   6.329468e+02   0.000000e+00     35s
#   130501    2.2167494e+05   7.205664e+02   0.000000e+00     40s
#   139670    2.2245581e+05   5.958326e+02   0.000000e+00     45s
#   148077    2.2307506e+05   5.695122e+02   0.000000e+00     50s
#   155705    2.2353295e+05   2.681437e+02   0.000000e+00     55s
#   163411    2.2387487e+05   1.057977e+02   0.000000e+00     60s
#   170190    2.2398357e+05   0.000000e+00   0.000000e+00     65s
#
# Root relaxation: objective 2.239836e+05, 170190 iterations, 64.53 seconds (252.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 223983.572    0    1 228986.210 223983.572  2.18%     -   64s
# H    0     0                    223983.57162 223983.572  0.00%     -   64s
#      0     0 223983.572    0    1 223983.572 223983.572  0.00%     -   64s
#
# Explored 1 nodes (170190 simplex iterations) in 65.00 seconds (252.61 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 223984 228986
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.239835716169e+05, best bound 2.239835716169e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 64000 rows, 122800 columns and 370400 nonzeros
# Model fingerprint: 0x5d963c95
# Model has 800 quadratic objective terms
# Variable types: 122000 continuous, 800 integer (800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Found heuristic solution: objective 241486.78000
# Presolve removed 44853 rows and 71643 columns
# Presolve time: 0.32s
# Presolved: 19147 rows, 51157 columns, 169607 nonzeros
# Presolved model has 655 quadratic objective terms
# Variable types: 50574 continuous, 583 integer (583 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    37619    1.4285436e+05   3.516627e+03   0.000000e+00      5s
#    58203    1.6477298e+05   2.949747e+03   0.000000e+00     10s
#    72777    1.7553519e+05   2.765366e+03   0.000000e+00     15s
#    85489    1.8277351e+05   2.103558e+03   0.000000e+00     20s
#    97079    1.8682568e+05   8.320959e+03   0.000000e+00     25s
#   107993    1.9364681e+05   2.023293e+03   0.000000e+00     30s
#   118275    1.9646701e+05   3.074809e+03   0.000000e+00     35s
#   127699    1.9981146e+05   4.559636e+03   0.000000e+00     40s
#   137259    2.0415992e+05   8.313121e+03   0.000000e+00     45s
#   146439    2.0699598e+05   3.817445e+03   0.000000e+00     50s
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.320689176868e+05, best bound 2.320689176868e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 80000 rows, 153500 columns and 463000 nonzeros
# Model fingerprint: 0x2bc99691
# Model has 1000 quadratic objective terms
# Variable types: 152500 continuous, 1000 integer (1000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Presolve removed 58999 rows and 98689 columns
# Presolve time: 0.37s
# Presolved: 21001 rows, 54811 columns, 183567 nonzeros
# Presolved model has 759 quadratic objective terms
# Variable types: 54136 continuous, 675 integer (675 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    37209    1.5615595e+05   2.413648e+03   0.000000e+00      5s
#    57183    1.7117144e+05   1.683256e+03   0.000000e+00     10s
#    72275    1.8307347e+05   2.640700e+03   0.000000e+00     15s
#    84889    1.8927702e+05   2.507406e+03   0.000000e+00     20s
#    96290    1.9731473e+05   3.315372e+03   0.000000e+00     25s
#   106965    2.0297311e+05   3.462448e+03   0.000000e+00     30s
#   117022    2.0712465e+05   1.804962e+03   0.000000e+00     35s
#   126763    2.0980122e+05   7.584088e+03   0.000000e+00     40s
#   136668    2.1125128e+05   2.484222e+03   0.000000e+00     45s
#   145897    2.1256270e+05   3.348861e+03   0.000000e+00     50s
#   154788    2.1453069e+05   9.250460e+03   0.000000e+00     55s
#   162749    2.1528358e+05   3.231891e+03   0.000000e+00     60s
#   170679    2.1612198e+05   5.276628e+03   0.000000e+00     65s
#   178137    2.1686536e+05   1.914640e+03   0.000000e+00     70s
#   185340    2.1794962e+05   5.278781e+03   0.000000e+00     75s
#   191870    2.1853367e+05   2.286976e+03   0.000000e+00     80s
#   198908    2.1917219e+05   1.238963e+03   0.000000e+00     85s
#   205718    2.1952158e+05   1.807259e+03   0.000000e+00     90s
#   212502    2.2000347e+05   3.640573e+03   0.000000e+00     95s
#   218819    2.2039057e+05   4.231241e+03   0.000000e+00    100s
#   225296    2.2084375e+05   1.898268e+03   0.000000e+00    105s
#   231767    2.2122310e+05   1.216809e+03   0.000000e+00    110s
#   238240    2.2174231e+05   5.198540e+03   0.000000e+00    115s
#   244407    2.2216652e+05   5.559857e+03   0.000000e+00    120s
#   250703    2.2251789e+05   1.684595e+03   0.000000e+00    125s
#   256597    2.2293330e+05   2.595785e+03   0.000000e+00    130s
#   262488    2.2322736e+05   4.561580e+03   0.000000e+00    135s
#   268126    2.2356301e+05   1.758021e+03   0.000000e+00    140s
#   273710    2.2387215e+05   7.818142e+03   0.000000e+00    145s
#   279470    2.2409470e+05   1.843097e+03   0.000000e+00    150s
#   285242    2.2434628e+05   1.702741e+03   0.000000e+00    155s
#   290876    2.2458914e+05   2.900667e+03   0.000000e+00    160s
#   296866    2.2497874e+05   1.061210e+03   0.000000e+00    165s
#   302263    2.2514003e+05   8.931457e+02   0.000000e+00    170s
#   307970    2.2550912e+05   1.905296e+03   0.000000e+00    175s
#   313520    2.2565856e+05   1.261016e+04   0.000000e+00    180s
#   319180    2.2584518e+05   7.906842e+02   0.000000e+00    185s
#   324580    2.2598808e+05   3.172526e+03   0.000000e+00    190s
#   330100    2.2613779e+05   1.069893e+03   0.000000e+00    195s
#   335837    2.2625755e+05   2.026540e+03   0.000000e+00    200s
