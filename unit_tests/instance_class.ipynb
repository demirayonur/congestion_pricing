# %%
import sys

sys.path.insert(1, '/Users/od721/Desktop/congestion_pricing/src')

import random_instance

# %%
n_node, n_arc, n_commodity, my_seed = 7,10,4,10

# %%
our_instance = random_instance.Instance(n_node, n_arc, n_commodity, my_seed)

# %%
our_instance.draw_graph()

# %%
for c in our_instance.commodities:
    com = our_instance.commodities[c]
    print('origin: ' +str(com[0]) + ' - '  'destination: ' +str(com[1]) )
# Out:
# origin: 4 - destination: 0
# origin: 1 - destination: 3
# origin: 6 - destination: 3
# origin: 6 - destination: 2
