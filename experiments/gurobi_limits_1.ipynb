# %%
import sys

sys.path.insert(1, '/Users/od721/Desktop/congestion_pricing/src')

import random_instance
import gurobi_base

import pandas as pd
import numpy as np
import time

# %%
coms = [150]
seeds = [40]
network_opts = [(300,600), (350,700), (400,800),(500,1000)]

for n_commodity in coms:
    for seed in seeds:
        print('ncom_' + str(n_commodity) + '_seed_' + str(seed))
        head_ = '/Users/od721/Desktop/congestion_pricing/results/gurobi_limits/seed_'
        path_ =  head_ + str(seed) + '_k_' + str(n_commodity) + '.xlsx'
        node_ls, arc_ls = [], []
        gurobi_obj_ls, gurobi_gap_ls, gurobi_time_ls = [], [], []
        for opt in network_opts:

            # get the instance
            n_node, n_arc = opt
            node_ls.append(n_node)
            arc_ls.append(n_arc)
            ins_ = random_instance.Instance(n_node, n_arc, n_commodity, seed)

            # gurobi stats
            gurobi_start = time.time()
            obj_gurobi, gap_gurobi, _ = gurobi_base.optimize_by_gurobi(ins_, 3600, log_output=True)
            gurobi_final = time.time()
            time_gurobi = round(gurobi_final - gurobi_start, 3)
            gurobi_obj_ls.append(round(obj_gurobi,2))
            gurobi_gap_ls.append(round(gap_gurobi,2))
            gurobi_time_ls.append(time_gurobi)

        df = pd.DataFrame()
        df['num_node'] = node_ls
        df['num_arc'] = arc_ls
        df['gurobi obj'] = gurobi_obj_ls
        df['gurobi gap'] = gurobi_gap_ls
        df['gurobi time (sec)'] = gurobi_time_ls
        df.to_excel(path_, index=False)
# Out:
# ncom_150_seed_40
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-07-12
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 48000 rows, 92100 columns and 277800 nonzeros
# Model fingerprint: 0x8f1202bb
# Model has 600 quadratic objective terms
# Variable types: 91500 continuous, 600 integer (600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Presolve removed 34646 rows and 58475 columns
# Presolve time: 0.19s
# Presolved: 13354 rows, 33625 columns, 117049 nonzeros
# Presolved model has 478 quadratic objective terms
# Variable types: 33264 continuous, 361 integer (361 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    38718    1.9520917e+05   3.824768e+03   0.000000e+00      5s
#    56538    2.1354079e+05   7.792308e+02   0.000000e+00     10s
#    69388    2.1980550e+05   1.116008e+03   0.000000e+00     15s
#    80306    2.2348793e+05   5.352428e+02   0.000000e+00     20s
#    90834    2.2499598e+05   4.227885e+01   0.000000e+00     25s
#    93414    2.2506959e+05   0.000000e+00   0.000000e+00     26s
#
# Root relaxation: objective 2.250696e+05, 93414 iterations, 26.25 seconds (104.91 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 225069.585    0    2          - 225069.585      -     -   26s
# H    0     0                    225069.58527 225069.585  0.00%     -   26s
#
# Explored 1 nodes (93414 simplex iterations) in 26.54 seconds (105.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 225070
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.250695852712e+05, best bound 2.250695852712e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 56000 rows, 107450 columns and 324100 nonzeros
# Model fingerprint: 0xbb91fe75
# Model has 700 quadratic objective terms
# Variable types: 106750 continuous, 700 integer (700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Presolve removed 40507 rows and 67486 columns
# Presolve time: 0.26s
# Presolved: 15493 rows, 39964 columns, 139494 nonzeros
# Presolved model has 562 quadratic objective terms
# Variable types: 39524 continuous, 440 integer (440 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    39031    1.7988330e+05   2.266705e+03   0.000000e+00      5s
#    57047    1.9615362e+05   2.440553e+03   0.000000e+00     10s
#    71274    2.0209874e+05   3.893432e+03   0.000000e+00     15s
#    83734    2.0824804e+05   1.771746e+03   0.000000e+00     20s
#    95285    2.1435123e+05   3.954569e+03   0.000000e+00     25s
#   106105    2.1688361e+05   1.265270e+03   0.000000e+00     30s
#   115456    2.1939801e+05   2.280680e+03   0.000000e+00     35s
#   124124    2.2055948e+05   5.629621e+02   0.000000e+00     40s
#   132244    2.2153181e+05   5.561502e+02   0.000000e+00     45s
#   139824    2.2230079e+05   2.275363e+02   0.000000e+00     50s
#   147586    2.2266342e+05   8.227965e+01   0.000000e+00     55s
#   150900    2.2274832e+05   0.000000e+00   0.000000e+00     58s
#
# Root relaxation: objective 2.227483e+05, 150900 iterations, 57.22 seconds (226.86 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    222748.32113 222748.321  0.00%     -   57s
#
# Explored 1 nodes (150900 simplex iterations) in 57.82 seconds (227.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 222748
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.227483211274e+05, best bound 2.227483211274e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 64000 rows, 122800 columns and 370400 nonzeros
# Model fingerprint: 0x75e8de07
# Model has 800 quadratic objective terms
# Variable types: 122000 continuous, 800 integer (800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+03]
#   Objective range  [2e+00, 2e+00]
#   QObjective range [2e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 9e+03]
# Found heuristic solution: objective 230175.24000
# Presolve removed 44406 rows and 71778 columns
# Presolve time: 0.31s
# Presolved: 19594 rows, 51022 columns, 172241 nonzeros
# Presolved model has 656 quadratic objective terms
# Variable types: 50472 continuous, 550 integer (550 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    41394    1.4754765e+05   3.822396e+03   0.000000e+00      5s
#    60859    1.6918641e+05   1.856804e+04   0.000000e+00     10s
#    77101    1.8221459e+05   2.523612e+03   0.000000e+00     15s
#    91890    1.9068948e+05   2.332128e+03   0.000000e+00     20s
#   105163    1.9426136e+05   2.248668e+03   0.000000e+00     25s
#   117816    1.9744285e+05   1.491681e+03   0.000000e+00     30s
#   129228    2.0026290e+05   3.942619e+03   0.000000e+00     35s
#   140293    2.0405685e+05   1.654617e+03   0.000000e+00     40s
#   150241    2.0613614e+05   3.209550e+03   0.000000e+00     45s
#   159781    2.0810893e+05   7.910023e+03   0.000000e+00     50s
#   168538    2.0963001e+05   2.584593e+03   0.000000e+00     55s
#   176924    2.1206202e+05   2.485846e+03   0.000000e+00     60s
#   185425    2.1317731e+05   1.357848e+03   0.000000e+00     65s
#   193820    2.1422850e+05   1.124537e+04   0.000000e+00     70s
#   202119    2.1500370e+05   1.221969e+03   0.000000e+00     75s
#   210230    2.1571672e+05   3.095217e+03   0.000000e+00     80s
#   217641    2.1640102e+05   1.155714e+03   0.000000e+00     85s
#   225103    2.1718811e+05   4.018846e+03   0.000000e+00     90s
#   232448    2.1761343e+05   2.110631e+03   0.000000e+00     95s
#   239902    2.1803682e+05   5.509505e+03   0.000000e+00    100s
#   247227    2.1842729e+05   1.098914e+03   0.000000e+00    105s
#   254239    2.1924252e+05   1.229793e+03   0.000000e+00    110s
#   260855    2.1965615e+05   1.526630e+03   0.000000e+00    115s
#   267328    2.2004110e+05   2.587588e+03   0.000000e+00    120s
#   273730    2.2040496e+05   2.000283e+03   0.000000e+00    125s
#   280086    2.2077686e+05   9.612171e+02   0.000000e+00    130s
#   285936    2.2107757e+05   7.015168e+02   0.000000e+00    135s
#   291836    2.2137934e+05   1.309076e+03   0.000000e+00    140s
#   297426    2.2161662e+05   7.006506e+02   0.000000e+00    145s
#   303036    2.2184332e+05   5.555579e+03   0.000000e+00    150s
#   308516    2.2203524e+05   2.644756e+03   0.000000e+00    155s
#   313966    2.2223029e+05   8.980513e+02   0.000000e+00    160s
#   319476    2.2241792e+05   8.863730e+02   0.000000e+00    165s
#   324506    2.2259154e+05   9.612568e+02   0.000000e+00    170s
#   329616    2.2277675e+05   6.175570e+02   0.000000e+00    175s
#   334636    2.2296336e+05   9.095702e+02   0.000000e+00    180s
#   339656    2.2316615e+05   5.547572e+02   0.000000e+00    185s
#   344596    2.2334097e+05   4.907287e+02   0.000000e+00    190s
#   349556    2.2352824e+05   3.304519e+02   0.000000e+00    195s
#   354046    2.2366798e+05   2.591505e+02   0.000000e+00    200s
#   358676    2.2378948e+05   3.521266e+02   0.000000e+00    205s
#   363492    2.2392051e+05   1.614490e+02   0.000000e+00    210s
#   368002    2.2401458e+05   1.123785e+02   0.000000e+00    215s
#   372332    2.2410763e+05   3.979530e+01   0.000000e+00    220s
#   376842    2.2414421e+05   6.185802e+00   0.000000e+00    225s
#   388670    2.2414478e+05   0.000000e+00   0.000000e+00    227s
# Root relaxation: objective 2.241448e+05, 388670 iterations, 226.21 seconds (908.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 224144.779    0    2 230175.240 224144.779  2.62%     -  226s
# H    0     0                    224144.77875 224144.779  0.00%     -  226s
#      0     0 224144.779    0    2 224144.779 224144.779  0.00%     -  226s
#
# Explored 1 nodes (388670 simplex iterations) in 226.72 seconds (908.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 224145
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.241447787470e+05, best bound 2.241447787470e+05, gap 0.0000%
# Set parameter TimeLimit to value 3600
