# %%
from gurobipy import GRB
import gurobipy as gp
import numpy as np
np.random.seed(0)
import math

# %% [markdown]
# #### let's try to solve large scale cutting stock problem to see if the licence is adequately introduced to the environment.

# %%
class Instance(object):
    
    def __init__(self, num_order, min_order_len=10, max_order_len=50,
                min_demand=1, max_demand=5):
        
        # generates an instance which guarantees feasibility.
        self.n = num_order
        self.order_lens = np.random.randint(min_order_len, max_order_len+1, size=self.n)
        self.demands = np.random.randint(min_demand, max_demand+1, size=self.n)
        self.m = np.sum(self.demands)
        self.roll_len = max_order_len
    
    def summarize(self):
        print("Problem instance with ", self.n, " orders and ", self.m, "rolls")
        print("-"*47)
        print("\nOrders:\n")
        for i, order_len in enumerate(self.order_lens):
            print("\tOrder ", i, ": length= ", order_len, " demand=", self.demands[i])
        print("\nRoll Length: ", self.roll_len)

# %%
def optimize_kantorovich(ins_:Instance):
    
    # model
    model = gp.Model("kantorovich_formulation")
    
    # sets (ranges)
    rolls = range(ins_.m)
    orders = range(ins_.n)
    
    # decision variables
    use_roll = model.addVars(rolls,
                             vtype=GRB.BINARY,
                             obj=np.ones(ins_.m),
                             name="X")
    
    how_much_use = model.addVars(orders, rolls, 
                                 vtype=GRB.INTEGER,
                                 obj= np.zeros((ins_.n, ins_.m)), 
                                 name="Y")
    
    '''
    We could also use looping to 
    generate decision variables: 
    
    Example for "use_roll":
    -----------------------
    use_roll = []
    for j in rolls:
        use_roll.append(model.addVar(vtype=GRB.BINARY,
                                     obj=1,
                                     name="X[%d]" %p ))
    Example for "how_much_use":
    ---------------------------
    how_much_use = []
    for j in rolls:
        how_much_use.append([])
        for i in orders:
            how_much_use[j].append(model.addVar(...))
    '''
    
    # direction of optimization (min or max)
    model.modelSense = GRB.MINIMIZE
    
    # demand satisfaction constraint
    model.addConstrs(
                    (how_much_use.sum(i, '*') == ins_.demands[i] for i in orders), 
                    "Demand"
                    )
    
    # length constraint of a roll
    for j in rolls:
        model.addConstr(sum(how_much_use[i,j]*ins_.order_lens[i] for i in orders)
                        <= ins_.roll_len,
                        "Length[%d]" %j)
    
    # x-y link
    for i in orders:
        for j in rolls:
            model.addConstr(how_much_use[i,j] <= use_roll[j]*ins_.demands[i])
    
    if False:
        model.write('kantorovich.lp') # in case you want to write the model
    
    # solve
    model.optimize()
    
    # display objective function value
    print('\nTotal Number of Rolls Used: ', model.objVal)

# %%
instance = Instance(100)
instance.summarize()
# Out:
# Problem instance with  100  orders and  283 rolls
# -----------------------------------------------
#
# Orders:
#
# 	Order  0 : length=  10  demand= 1
# 	Order  1 : length=  13  demand= 2
# 	Order  2 : length=  13  demand= 1
# 	Order  3 : length=  49  demand= 3
# 	Order  4 : length=  19  demand= 3
# 	Order  5 : length=  29  demand= 4
# 	Order  6 : length=  31  demand= 3
# 	Order  7 : length=  46  demand= 4
# 	Order  8 : length=  33  demand= 3
# 	Order  9 : length=  16  demand= 2
# 	Order  10 : length=  34  demand= 3
# 	Order  11 : length=  34  demand= 4
# 	Order  12 : length=  22  demand= 4
# 	Order  13 : length=  11  demand= 4
# 	Order  14 : length=  48  demand= 3
# 	Order  15 : length=  49  demand= 4
# 	Order  16 : length=  33  demand= 5
# 	Order  17 : length=  34  demand= 2
# 	Order  18 : length=  27  demand= 3
# 	Order  19 : length=  47  demand= 4
# 	Order  20 : length=  35  demand= 2
# 	Order  21 : length=  23  demand= 3
# 	Order  22 : length=  18  demand= 2
# 	Order  23 : length=  19  demand= 5
# 	Order  24 : length=  30  demand= 3
# 	Order  25 : length=  26  demand= 4
# 	Order  26 : length=  15  demand= 1
# 	Order  27 : length=  25  demand= 4
# 	Order  28 : length=  10  demand= 3
# 	Order  29 : length=  28  demand= 4
# 	Order  30 : length=  45  demand= 1
# 	Order  31 : length=  34  demand= 1
# 	Order  32 : length=  39  demand= 1
# 	Order  33 : length=  29  demand= 4
# 	Order  34 : length=  29  demand= 3
# 	Order  35 : length=  24  demand= 4
# 	Order  36 : length=  49  demand= 1
# 	Order  37 : length=  42  demand= 5
# 	Order  38 : length=  11  demand= 1
# 	Order  39 : length=  19  demand= 1
# 	Order  40 : length=  42  demand= 3
# 	Order  41 : length=  41  demand= 4
# 	Order  42 : length=  20  demand= 3
# 	Order  43 : length=  33  demand= 4
# 	Order  44 : length=  45  demand= 1
# 	Order  45 : length=  21  demand= 1
# 	Order  46 : length=  38  demand= 1
# 	Order  47 : length=  44  demand= 4
# 	Order  48 : length=  10  demand= 1
# 	Order  49 : length=  10  demand= 3
# 	Order  50 : length=  46  demand= 3
# 	Order  51 : length=  15  demand= 1
# 	Order  52 : length=  48  demand= 5
# 	Order  53 : length=  50  demand= 4
# 	Order  54 : length=  27  demand= 5
# 	Order  55 : length=  25  demand= 1
# 	Order  56 : length=  14  demand= 5
# 	Order  57 : length=  41  demand= 4
# 	Order  58 : length=  11  demand= 4
# 	Order  59 : length=  11  demand= 5
# 	Order  60 : length=  49  demand= 2
# 	Order  61 : length=  45  demand= 4
# 	Order  62 : length=  48  demand= 1
# 	Order  63 : length=  21  demand= 1
# 	Order  64 : length=  28  demand= 1
# 	Order  65 : length=  37  demand= 2
# 	Order  66 : length=  10  demand= 1
# 	Order  67 : length=  24  demand= 5
# 	Order  68 : length=  45  demand= 2
# 	Order  69 : length=  22  demand= 4
# 	Order  70 : length=  30  demand= 2
# 	Order  71 : length=  21  demand= 1
# 	Order  72 : length=  14  demand= 1
# 	Order  73 : length=  16  demand= 5
# 	Order  74 : length=  14  demand= 4
# 	Order  75 : length=  13  demand= 4
# 	Order  76 : length=  22  demand= 2
# 	Order  77 : length=  46  demand= 1
# 	Order  78 : length=  50  demand= 1
# 	Order  79 : length=  24  demand= 2
# 	Order  80 : length=  25  demand= 3
# 	Order  81 : length=  30  demand= 1
# 	Order  82 : length=  45  demand= 4
# 	Order  83 : length=  33  demand= 2
# 	Order  84 : length=  25  demand= 2
# 	Order  85 : length=  23  demand= 5
# 	Order  86 : length=  31  demand= 1
# 	Order  87 : length=  15  demand= 1
# 	Order  88 : length=  45  demand= 4
# 	Order  89 : length=  10  demand= 3
# 	Order  90 : length=  41  demand= 4
# 	Order  91 : length=  15  demand= 3
# 	Order  92 : length=  40  demand= 5
# 	Order  93 : length=  10  demand= 4
# 	Order  94 : length=  46  demand= 4
# 	Order  95 : length=  44  demand= 1
# 	Order  96 : length=  39  demand= 4
# 	Order  97 : length=  13  demand= 1
# 	Order  98 : length=  44  demand= 5
# 	Order  99 : length=  23  demand= 3
#
# Roll Length:  50

# %%
optimize_kantorovich(instance)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-07-12
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 28683 rows, 28583 columns and 113200 nonzeros
# Model fingerprint: 0x5ac7c015
# Variable types: 0 continuous, 28583 integer (283 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 14971 rows and 0 columns
# Presolve time: 0.26s
# Presolved: 13712 rows, 28583 columns, 174356 nonzeros
# Variable types: 0 continuous, 28583 integer (20093 binary)
# Found heuristic solution: objective 188.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 9.300000e+01, 24612 iterations, 0.31 seconds (0.62 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   93.00000    0  817  188.00000   93.00000  50.5%     -    2s
#      0     0   93.00000    0  764  188.00000   93.00000  50.5%     -    5s
